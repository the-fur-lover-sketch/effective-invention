# %% [markdown]
# <a href="https://colab.research.google.com/github/the-fur-lover-sketch/effective-invention/blob/main/SimCodeEmulator0102_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CdoStock={}
ParDict={}
def finire(Line):
  ParCdoLine = ParDict[Line]
  ScopeRest = CdoStock[ParCdoLine]['Rest']
  ScopeRest[Line]['Num'] -= 1
  for line in ScopeRest[Line]['Tree']:
    ScopeRest[line]['Num'] -= 1

def finire():
  pass

# %%
Scope
